# %%
from spleeter.separator import Separator

# %%
separator = Separator('spleeter:4stems')

# %%
separator.separate_to_file('../songs/raw_songs/01 The Spirit Of Radio.wma', '../songs/split_songs/')
