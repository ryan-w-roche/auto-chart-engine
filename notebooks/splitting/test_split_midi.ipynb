# %%
# Imports and Setup
from mido import MidiFile, MidiTrack, MetaMessage

import os
import unittest

# %%
def extract_drum_track(input_file, output_file):
    # Initialize MIDI files
    in_mid = MidiFile(input_file)
    out_mid = MidiFile(ticks_per_beat=in_mid.ticks_per_beat)
    
    # Create drum track
    drum_track = MidiTrack()
    out_mid.tracks.append(drum_track)
    
    # Collect messages with absolute times
    all_messages = []
    current_time = 0
    
    # Process each track
    for track in in_mid.tracks:
        current_time = 0
        for msg in track:
            current_time += msg.time
            if (isinstance(msg, MetaMessage) and msg.type in ('set_tempo', 'time_signature')) or \
               (msg.type in ('note_on', 'note_off') and msg.channel == 9) or \
               (msg.type not in ('note_on', 'note_off')):
                all_messages.append((current_time, msg))
    
    # Sort and convert to delta times
    all_messages.sort(key=lambda x: x[0])
    print([msg.channel for msg in all_messages if hasattr(msg, 'channel')])
    last_time = 0
    
    for abs_time, msg in all_messages:
        delta = abs_time - last_time
        new_msg = msg.copy(time=delta)
        drum_track.append(new_msg)
        last_time = abs_time
    
    # Save and return
    out_mid.save(output_file)
    return out_mid

# %%
# Define the input and output directories
input_file = '../../songs/raw_midi_songs/for those about to rock.mid'
output_file = '../../songs/split_midi_songs/test-split.mid'

extract_drum_track(input_file, output_file)
# Out:
# []
# MidiFile(type=1, ticks_per_beat=120, tracks=[
#   MidiTrack([
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('key_signature', key='D', time=0),
#     MetaMessage('set_tempo', tempo=444444, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='Vocal melody', time=0),
#     Message('program_change', channel=3, program=103, time=0),
#     Message('control_change', channel=3, control=7, value=110, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='Gtr I', time=0),
#     Message('program_change', channel=0, program=30, time=0),
#     Message('control_change', channel=0, control=7, value=70, time=0),
#     Message('control_change', channel=0, control=10, value=1, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='Gtr II', time=0),
#     Message('program_change', channel=1, program=29, time=0),
#     Message('control_change', channel=1, control=7, value=70, time=0),
#     Message('control_change', channel=1, control=10, value=64, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='Drums', time=0),
#     Message('program_change', channel=9, program=16, time=0),
#     Message('control_change', channel=9, control=7, value=115, time=0),
#     Message('control_change', channel=9, control=10, value=64, time=0),
#     Message('program_change', channel=9, program=16, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='bass', time=0),
#     Message('program_change', channel=2, program=34, time=0),
#     Message('control_change', channel=2, control=7, value=90, time=0),
#     Message('control_change', channel=2, control=10, value=64, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='EXPLOSION', time=0),
#     Message('program_change', channel=12, program=127, time=0),
#     Message('control_change', channel=12, control=7, value=127, time=0),
#     Message('control_change', channel=12, control=10, value=127, time=0),
#     Message('control_change', channel=12, control=93, value=127, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='SOLO GTR', time=0),
#     Message('program_change', channel=4, program=30, time=0),
#     Message('control_change', channel=4, control=7, value=105, time=0),
#     Message('control_change', channel=4, control=1, value=100, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('program_change', channel=11, program=127, time=0),
#     Message('control_change', channel=11, control=7, value=127, time=0),
#     Message('control_change', channel=11, control=10, value=1, time=0),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='Gtr II delay', time=0),
#     Message('program_change', channel=5, program=30, time=0),
#     Message('control_change', channel=5, control=7, value=70, time=0),
#     Message('control_change', channel=5, control=10, value=1, time=0),
#     Message('control_change', channel=5, control=93, value=127, time=0),
#     Message('control_change', channel=5, control=91, value=100, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='intro delay', time=0),
#     Message('program_change', channel=6, program=29, time=0),
#     Message('control_change', channel=6, control=7, value=80, time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('track_name', name='Gtr I', time=0),
#     Message('program_change', channel=7, program=29, time=0),
#     Message('control_change', channel=7, control=7, value=70, time=0),
#     Message('control_change', channel=7, control=10, value=127, time=0),
#     Message('control_change', channel=0, control=5, value=0, time=3600),
#     Message('control_change', channel=0, control=93, value=90, time=0),
#     Message('control_change', channel=1, control=5, value=0, time=0),
#     Message('control_change', channel=1, control=93, value=100, time=0),
#     Message('control_change', channel=9, control=93, value=90, time=0),
#     Message('control_change', channel=9, control=91, value=90, time=0),
#     Message('control_change', channel=2, control=1, value=30, time=0),
#     Message('control_change', channel=5, control=5, value=0, time=0),
#     Message('control_change', channel=5, control=93, value=100, time=0),
#     Message('control_change', channel=7, control=91, value=100, time=0),
#     Message('control_change', channel=7, control=93, value=90, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=240),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=43, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=43, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=43, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=43, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=43, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=43, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=43, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=43, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=43, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=43, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     MetaMessage('end_of_track', time=30),
#     Message('note_on', channel=9, note=38, velocity=0, time=30),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=180),
#     Message('note_on', channel=9, note=57, velocity=0, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=240),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=180),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=180),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('pitchwheel', channel=3, pitch=0, time=180),
#     Message('pitchwheel', channel=1, pitch=0, time=0),
#     Message('pitchwheel', channel=9, pitch=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('pitchwheel', channel=2, pitch=0, time=0),
#     Message('pitchwheel', channel=12, pitch=0, time=0),
#     Message('pitchwheel', channel=5, pitch=0, time=0),
#     Message('pitchwheel', channel=3, pitch=1, time=46),
#     Message('pitchwheel', channel=1, pitch=1, time=0),
#     Message('pitchwheel', channel=9, pitch=1, time=0),
#     Message('pitchwheel', channel=2, pitch=1, time=0),
#     Message('pitchwheel', channel=12, pitch=1, time=0),
#     Message('pitchwheel', channel=5, pitch=1, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=14),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('pitchwheel', channel=3, pitch=2, time=33),
#     Message('pitchwheel', channel=1, pitch=2, time=0),
#     Message('pitchwheel', channel=9, pitch=2, time=0),
#     Message('pitchwheel', channel=2, pitch=2, time=0),
#     Message('pitchwheel', channel=12, pitch=2, time=0),
#     Message('pitchwheel', channel=5, pitch=2, time=0),
#     Message('pitchwheel', channel=3, pitch=3, time=47),
#     Message('pitchwheel', channel=1, pitch=3, time=0),
#     Message('pitchwheel', channel=9, pitch=3, time=0),
#     Message('pitchwheel', channel=2, pitch=3, time=0),
#     Message('pitchwheel', channel=12, pitch=3, time=0),
#     Message('pitchwheel', channel=5, pitch=3, time=0),
#     Message('pitchwheel', channel=3, pitch=4, time=46),
#     Message('pitchwheel', channel=1, pitch=4, time=0),
#     Message('pitchwheel', channel=9, pitch=4, time=0),
#     Message('pitchwheel', channel=2, pitch=4, time=0),
#     Message('pitchwheel', channel=12, pitch=4, time=0),
#     Message('pitchwheel', channel=5, pitch=4, time=0),
#     Message('pitchwheel', channel=3, pitch=5, time=47),
#     Message('pitchwheel', channel=1, pitch=5, time=0),
#     Message('pitchwheel', channel=9, pitch=5, time=0),
#     Message('pitchwheel', channel=2, pitch=5, time=0),
#     Message('pitchwheel', channel=12, pitch=5, time=0),
#     Message('pitchwheel', channel=5, pitch=5, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=7),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('pitchwheel', channel=3, pitch=6, time=40),
#     Message('pitchwheel', channel=1, pitch=6, time=0),
#     Message('pitchwheel', channel=9, pitch=6, time=0),
#     Message('pitchwheel', channel=2, pitch=6, time=0),
#     Message('pitchwheel', channel=12, pitch=6, time=0),
#     Message('pitchwheel', channel=5, pitch=6, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=20),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('pitchwheel', channel=3, pitch=7, time=26),
#     Message('pitchwheel', channel=1, pitch=7, time=0),
#     Message('pitchwheel', channel=9, pitch=7, time=0),
#     Message('pitchwheel', channel=2, pitch=7, time=0),
#     Message('pitchwheel', channel=12, pitch=7, time=0),
#     Message('pitchwheel', channel=5, pitch=7, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=34),
#     Message('pitchwheel', channel=3, pitch=8, time=13),
#     Message('pitchwheel', channel=1, pitch=8, time=0),
#     Message('pitchwheel', channel=9, pitch=8, time=0),
#     Message('pitchwheel', channel=2, pitch=8, time=0),
#     Message('pitchwheel', channel=12, pitch=8, time=0),
#     Message('pitchwheel', channel=5, pitch=8, time=0),
#     Message('pitchwheel', channel=3, pitch=9, time=47),
#     Message('pitchwheel', channel=1, pitch=9, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('pitchwheel', channel=9, pitch=9, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('pitchwheel', channel=2, pitch=9, time=0),
#     Message('pitchwheel', channel=12, pitch=9, time=0),
#     Message('pitchwheel', channel=5, pitch=9, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=120),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=240),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=60),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=30),
#     Message('note_on', channel=9, note=57, velocity=0, time=90),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=30),
#     Message('note_on', channel=9, note=35, velocity=0, time=90),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=30),
#     Message('note_on', channel=9, note=35, velocity=0, time=90),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=45, velocity=127, time=0),
#     Message('note_on', channel=9, note=45, velocity=0, time=60),
#     Message('note_on', channel=9, note=47, velocity=127, time=0),
#     Message('note_on', channel=9, note=47, velocity=0, time=60),
#     Message('note_on', channel=9, note=43, velocity=127, time=0),
#     Message('note_on', channel=9, note=43, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=120),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=120),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=42, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=30),
#     Message('note_on', channel=9, note=38, velocity=0, time=90),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=120),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=30),
#     Message('note_on', channel=9, note=35, velocity=0, time=90),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=127, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=60),
# ...
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=120),
#     Message('note_on', channel=9, note=57, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=30),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=30),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=30),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=30),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=127, time=60),
#     Message('note_on', channel=9, note=35, velocity=0, time=60),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('control_change', channel=0, control=7, value=76, time=47),
#     Message('control_change', channel=4, control=7, value=76, time=0),
#     Message('control_change', channel=7, control=7, value=76, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=73),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=38, velocity=127, time=0),
#     Message('note_on', channel=9, note=38, velocity=0, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=35, velocity=0, time=180),
#     MetaMessage('end_of_track', time=120),
#     Message('note_on', channel=9, note=49, velocity=0, time=120),
#     MetaMessage('set_tempo', tempo=1463415, time=478),
#     Message('note_on', channel=9, note=49, velocity=127, time=2),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('control_change', channel=0, control=7, value=75, time=14),
#     Message('control_change', channel=4, control=7, value=75, time=0),
#     MetaMessage('end_of_track', time=0),
#     Message('control_change', channel=7, control=7, value=75, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=1),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     Message('note_on', channel=9, note=46, velocity=127, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=15),
#     MetaMessage('set_tempo', tempo=458015, time=2),
#     Message('note_on', channel=9, note=49, velocity=127, time=238),
#     Message('note_on', channel=9, note=49, velocity=0, time=60),
#     Message('note_on', channel=9, note=35, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=120),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=127, time=60),
#     Message('note_on', channel=9, note=49, velocity=127, time=0),
#     Message('note_on', channel=9, note=49, velocity=0, time=15),
#     Message('note_on', channel=9, note=57, velocity=0, time=0),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('end_of_track', time=105),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('end_of_track', time=0),
#     MetaMessage('set_tempo', tempo=545455, time=496),
#     MetaMessage('set_tempo', tempo=540541, time=24),
#     MetaMessage('set_tempo', tempo=535714, time=4),
#     MetaMessage('end_of_track', time=0)])
# ])

# %%
class TestMidiDrumExtractor(unittest.TestCase):
    def setUp(self):
        self.input_file = '../../songs/raw_midi_songs/for those about to rock.mid'
        self.output_file = '../../songs/split_midi_songs/test-split.mid'
    
    def test_file_creation(self):
        """Test if output file is created"""
        result = extract_drum_track(self.input_file, self.output_file)
        self.assertTrue(os.path.exists(self.output_file))
    
    def test_output_structure(self):
        """Test if output MIDI has correct structure"""
        result = extract_drum_track(self.input_file, self.output_file)
        self.assertIsInstance(result, MidiFile)
        self.assertEqual(len(result.tracks), 1)
    
    def test_drum_channel(self):
        """Test if output contains only drum channel messages"""
        result = extract_drum_track(self.input_file, self.output_file)
        for track in result.tracks:
            for msg in track:
                if hasattr(msg, 'channel') and msg.type == 'note_on':
                    self.assertEqual(msg.channel, 9)
    
    def test_no_non_drum_messages(self):
        """Test that no non-drum messages exist in the output."""
        result = extract_drum_track(self.input_file, self.output_file)
        for track in result.tracks:
            for msg in track:
                if hasattr(msg, 'channel') and msg.type == 'note_on':
                    self.assertEqual(msg.channel, 9)
                else:
                    self.assertNotIn(msg.type, ['note_on', 'note_off'])

    def test_timing_accuracy(self):
        """Test that drum messages maintain accurate timing."""
        original_mid = MidiFile(self.input_file)
        result = extract_drum_track(self.input_file, self.output_file)
        
        original_times = []
        result_times = []
        
        for track in original_mid.tracks:
            current_time = 0
            for msg in track:
                current_time += msg.time
                if hasattr(msg, 'channel') and msg.channel == 9:
                    original_times.append(current_time)
        
        current_time = 0
        for track in result.tracks:
            for msg in track:
                current_time += msg.time
                if hasattr(msg, 'channel') and msg.channel == 9:
                    result_times.append(current_time)
        
        self.assertEqual(original_times, result_times)

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# []
# .
# []
# []
# .
# []
# .
# []
# .
# ----------------------------------------------------------------------
# Ran 5 tests in 0.612s
#
# OK
